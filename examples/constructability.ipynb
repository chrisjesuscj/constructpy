# %% [markdown]
# # Constructpy Example Usecase
#
# This notebook showcases some basic usage of the constructpy library

# %%
from constructpy import Constructability
import ifcopenshell
import ifcopenshell.geom
import k3d
import matplotlib.pyplot as plt
import numpy as np
import collections

# %% [markdown]
# Constructpy needs an IFC file loaded into a ifcopenshell.file object:

# %%
ifc_file = 'rstadvancedsampleproject_patched.ifc'
ifc = ifcopenshell.open(ifc_file)

# %% [markdown]
# Create a Constructability object passing optional weights (this might take a few seconds as it does all the calculations).
# The Constructability object instanciates the Standardization, Simplicity and Accessibility objects and executes all constructability assessments methods available. It also takes optional weights used in the calculations. More information ond the existing methods in the [documentation](https://chrisjesuscj.github.io/constructpy/).

# %%
# Set weights for main constructability calculation
standadization_weight = 0.8
simplicity_weight = 1.0
accessibility_weight = 0.6

# Create a constructability object passing the ifc and weights
con = Constructability(ifc, standadization_weight, simplicity_weight, accessibility_weight)

# %% [markdown]
# The data created from the Constructability object can be accessed by its attributes, as shown below, where the data is being organized to feed a matplotlib chart:

# %%
# Data and Text Labels
data = {
    'Accessibility': [con.accessibility.location_score, con.accessibility.area_score],
    'Simplicity': [con.simplicity.pcast_score, con.simplicity.length_score, con.simplicity.basement_score],
    'Standardization': [con.standardization.floor2floor_height_score, con.standardization.structural_types_score],
    'Constructability': [con.accessibility_score, con.simplicity_score, con.standardization_score, con.constructability_score]
}

text_labels = {
    'Accessibility': ['Location', 'Built Area'],
    'Simplicity': ['Precast Elements', 'Length of Beams', 'Has Basement'],
    'Standardization': ['Floor to Floor Height', 'Structural Types'],
    'Constructability': ['Accessibility Score', 'Simplicity Score', 'Standardization Score', 'Constructability Score']
}

# %% [markdown]
# The script below creates a matplotlib chart breaking down all the constructability scores calculated for an easy overview:

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.style.use('seaborn-v0_8')

k, v = zip(*data.items())
max_n_bars = max(len(v) for v in data.values())
group_centers = np.cumsum([max_n_bars for _ in data.items()]) - (max_n_bars / 2)
bar_offset = (1 - 0.95) / 2
bars = collections.defaultdict(list)

colors = {g_name: [f"C{i}" for _ in values] for i, (g_name, values) in enumerate(data.items())}

for g_i, ((g_name, vals), g_center) in enumerate(zip(data.items(), group_centers)):
    n_bars = len(vals)
    group_radius = 0.8 * (n_bars - 0.95) * 0.5
    group_beg = g_center - group_radius
    for val_i, val in enumerate(vals):
        val = val*100
        bar = ax.barh(group_beg + (val_i + bar_offset) * 0.8,  
                     width=val, height=0.95 * 0.8,
                     color=colors[g_name][val_i])[0]
        bars[g_name].append(bar)

        y_pos = bar.get_y() + (bar.get_height() / 2.0)
        x_pos = val + 0.2
        barlbl = f'{val:.1f}%'
        ax.text(x_pos, y_pos, barlbl, ha="left", va="center", fontsize=8)

        if text_labels and g_name in text_labels and val_i < len(text_labels[g_name]):
            text_label = text_labels[g_name][val_i]
            text_x_pos = x_pos - val - 1
            ax.text(text_x_pos, y_pos, text_label, ha="right", va="center", fontsize=8.5, color='black', weight='normal')

ax.legend([bars[k][0] for k in k], k, loc='upper center', ncols=4, bbox_to_anchor=(0.5,-0.05), shadow=True)
ax.set_yticks([])
ax.set_yticklabels([])
ax.spines[['right','top', 'bottom']].set_visible(True)
ax.spines['left'].set_visible(True)
ax.set_title("Constructability Chart")
# Out:
# Text(0.5, 1.0, 'Constructability Chart')

# %% [markdown]
# Aside from the scores, some other useful information can also be gathered from the objects, a few examples below:

# %%
# Getting information on site location
nearest_city = con.accessibility.location_city[0]
distance_city = con.accessibility.location_city[1]

print(f'The nearest city found is {nearest_city} at {distance_city:.2f} kilometers from the site.')

# Getting the beams that passed the length test
valid_beams = con.simplicity.valid_beams

# Getting the beams that didn't pass
invalid_beams = ifc.by_type("IfcBeam")
for beam in invalid_beams:
    if beam in valid_beams:
        invalid_beams.remove(beam)

print(f'The valid beams found are: {valid_beams}')
print(f'The invalid beams found are: {invalid_beams}')
# Out:
# The nearest city found is Mont-Tremblant at 24.64 kilometers from the site.
# The valid beams found are: [#2697=IfcBeam('1WrzGm1SD2ev45B_OWQ39H',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124565',$,'M_Concrete-Rectangular Beam:400 x 800mm',#2696,#2693,'124565',.BEAM.), #2858=IfcBeam('1WrzGm1SD2ev45B_OWQ39S',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124568',$,'M_Concrete-Rectangular Beam:400 x 800mm',#2857,#2854,'124568',.BEAM.), #3034=IfcBeam('1WrzGm1SD2ev45B_OWQ39V',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124571',$,'M_Concrete-Rectangular Beam:400 x 800mm',#3033,#3030,'124571',.BEAM.), #3387=IfcBeam('1WrzGm1SD2ev45B_OWQ39b',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124577',$,'M_Concrete-Rectangular Beam:400 x 800mm',#3386,#3383,'124577',.BEAM.), #3714=IfcBeam('1WrzGm1SD2ev45B_OWQ39Y',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124582',$,'M_Concrete-Rectangular Beam:400 x 800mm',#3713,#3710,'124582',.BEAM.), #3888=IfcBeam('1WrzGm1SD2ev45B_OWQ39j',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124585',$,'M_Concrete-Rectangular Beam:400 x 800mm',#3887,#3884,'124585',.BEAM.), #4049=IfcBeam('1WrzGm1SD2ev45B_OWQ39l',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124587',$,'M_Concrete-Rectangular Beam:400 x 800mm',#4048,#4045,'124587',.BEAM.), #4584=IfcBeam('1WrzGm1SD2ev45B_OWQ39s',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124594',$,'M_Concrete-Rectangular Beam:400 x 800mm',#4583,#4580,'124594',.BEAM.), #4762=IfcBeam('1WrzGm1SD2ev45B_OWQ39o',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124598',$,'M_Concrete-Rectangular Beam:400 x 800mm',#4761,#4758,'124598',.BEAM.), #4941=IfcBeam('1WrzGm1SD2ev45B_OWQ39y',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124600',$,'M_Concrete-Rectangular Beam:400 x 800mm',#4940,#4937,'124600',.BEAM.), #5296=IfcBeam('1WrzGm1SD2ev45B_OWQ39u',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124604',$,'M_Concrete-Rectangular Beam:400 x 800mm',#5295,#5292,'124604',.BEAM.), #5653=IfcBeam('1WrzGm1SD2ev45B_OWQ384',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124608',$,'M_Concrete-Rectangular Beam:400 x 800mm',#5652,#5649,'124608',.BEAM.), #5830=IfcBeam('1WrzGm1SD2ev45B_OWQ386',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124610',$,'M_Concrete-Rectangular Beam:400 x 800mm',#5829,#5826,'124610',.BEAM.), #6009=IfcBeam('1WrzGm1SD2ev45B_OWQ380',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124612',$,'M_Concrete-Rectangular Beam:400 x 800mm',#6008,#6005,'124612',.BEAM.), #6379=IfcBeam('1WrzGm1SD2ev45B_OWQ38C',#18,'M_Concrete-Rectangular Beam:300 x 600mm:124616',$,'M_Concrete-Rectangular Beam:300 x 600mm',#6378,#6375,'124616',.JOIST.), #6540=IfcBeam('1WrzGm1SD2ev45B_OWQ388',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124620',$,'M_Concrete-Rectangular Beam:400 x 800mm',#6539,#6536,'124620',.BEAM.), #6701=IfcBeam('1WrzGm1SD2ev45B_OWQ38A',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124622',$,'M_Concrete-Rectangular Beam:400 x 800mm',#6700,#6697,'124622',.BEAM.), #7034=IfcBeam('1WrzGm1SD2ev45B_OWQ38M',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124626',$,'M_Concrete-Rectangular Beam:400 x 800mm',#7033,#7030,'124626',.BEAM.), #7264=IfcBeam('1WrzGm1SD2ev45B_OWQ38I',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124630',$,'M_Concrete-Rectangular Beam:400 x 800mm',#7263,#7260,'124630',.BEAM.), #7423=IfcBeam('1WrzGm1SD2ev45B_OWQ38S',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124632',$,'M_Concrete-Rectangular Beam:400 x 800mm',#7422,#7419,'124632',.BEAM.), #7586=IfcBeam('1WrzGm1SD2ev45B_OWQ38U',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124634',$,'M_Concrete-Rectangular Beam:400 x 800mm',#7585,#7582,'124634',.BEAM.), #9298=IfcBeam('1WrzGm1SD2ev45B_OWQ38_',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124666',$,'M_Concrete-Rectangular Beam:400 x 800mm',#9297,#9294,'124666',.BEAM.), #9502=IfcBeam('1WrzGm1SD2ev45B_OWQ38v',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124669',$,'M_Concrete-Rectangular Beam:400 x 800mm',#9501,#9498,'124669',.BEAM.), #9706=IfcBeam('1WrzGm1SD2ev45B_OWQ3F4',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124672',$,'M_Concrete-Rectangular Beam:400 x 800mm',#9705,#9702,'1246 ...
# The invalid beams found are: [#2545=IfcBeam('1WrzGm1SD2ev45B_OWQ39B',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124559',$,'M_Concrete-Rectangular Beam:400 x 800mm',#2544,#2541,'124559',.BEAM.), #2858=IfcBeam('1WrzGm1SD2ev45B_OWQ39S',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124568',$,'M_Concrete-Rectangular Beam:400 x 800mm',#2857,#2854,'124568',.BEAM.), #3211=IfcBeam('1WrzGm1SD2ev45B_OWQ39Q',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124574',$,'M_Concrete-Rectangular Beam:400 x 800mm',#3210,#3207,'124574',.BEAM.), #3563=IfcBeam('1WrzGm1SD2ev45B_OWQ39d',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124579',$,'M_Concrete-Rectangular Beam:400 x 800mm',#3562,#3559,'124579',.BEAM.), #3888=IfcBeam('1WrzGm1SD2ev45B_OWQ39j',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124585',$,'M_Concrete-Rectangular Beam:400 x 800mm',#3887,#3884,'124585',.BEAM.), #4237=IfcBeam('1WrzGm1SD2ev45B_OWQ39g',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124590',$,'M_Concrete-Rectangular Beam:400 x 800mm',#4236,#4233,'124590',.BEAM.), #4404=IfcBeam('1WrzGm1SD2ev45B_OWQ39q',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124592',$,'M_Concrete-Rectangular Beam:400 x 800mm',#4403,#4400,'124592',.BEAM.), #4762=IfcBeam('1WrzGm1SD2ev45B_OWQ39o',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124598',$,'M_Concrete-Rectangular Beam:400 x 800mm',#4761,#4758,'124598',.BEAM.), #5119=IfcBeam('1WrzGm1SD2ev45B_OWQ39_',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124602',$,'M_Concrete-Rectangular Beam:400 x 800mm',#5118,#5115,'124602',.BEAM.), #5475=IfcBeam('1WrzGm1SD2ev45B_OWQ39w',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124606',$,'M_Concrete-Rectangular Beam:400 x 800mm',#5474,#5471,'124606',.BEAM.), #5830=IfcBeam('1WrzGm1SD2ev45B_OWQ386',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124610',$,'M_Concrete-Rectangular Beam:400 x 800mm',#5829,#5826,'124610',.BEAM.), #6225=IfcBeam('1WrzGm1SD2ev45B_OWQ382',#18,'M_Concrete-Rectangular Beam:300 x 600mm:124614',$,'M_Concrete-Rectangular Beam:300 x 600mm',#6224,#6221,'124614',.JOIST.), #6540=IfcBeam('1WrzGm1SD2ev45B_OWQ388',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124620',$,'M_Concrete-Rectangular Beam:400 x 800mm',#6539,#6536,'124620',.BEAM.), #6875=IfcBeam('1WrzGm1SD2ev45B_OWQ38K',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124624',$,'M_Concrete-Rectangular Beam:400 x 800mm',#6874,#6871,'124624',.BEAM.), #7150=IfcBeam('1WrzGm1SD2ev45B_OWQ38G',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124628',$,'M_Concrete-Rectangular Beam:400 x 800mm',#7149,#7146,'124628',.BEAM.), #7423=IfcBeam('1WrzGm1SD2ev45B_OWQ38S',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124632',$,'M_Concrete-Rectangular Beam:400 x 800mm',#7422,#7419,'124632',.BEAM.), #7766=IfcBeam('1WrzGm1SD2ev45B_OWQ38O',#18,'M_Concrete-Rectangular Beam:400 x 800mm:124636',$,'M_Concrete-Rectangular Beam:400 x 800mm',#7765,#7762,'124636',.BEAM.), #7943=IfcBeam('1WrzGm1SD2ev45B_OWQ38Q',#18,'M_Concrete-Rectangular Beam:300 x 600mm:124638',$,'M_Concrete-Rectangular Beam:300 x 600mm',#7942,#7939,'124638',.JOIST.), #8120=IfcBeam('1WrzGm1SD2ev45B_OWQ38X',#18,'M_Concrete-Rectangular Beam:300 x 600mm:124645',$,'M_Concrete-Rectangular Beam:300 x 600mm',#8119,#8116,'124645',.JOIST.), #8297=IfcBeam('1WrzGm1SD2ev45B_OWQ38Z',#18,'M_Concrete-Rectangular Beam:300 x 600mm:124647',$,'M_Concrete-Rectangular Beam:300 x 600mm',#8296,#8293,'124647',.JOIST.), #8474=IfcBeam('1WrzGm1SD2ev45B_OWQ38f',#18,'M_Concrete-Rectangular Beam:300 x 600mm:124653',$,'M_Concrete-Rectangular Beam:300 x 600mm',#8473,#8470,'124653',.JOIST.), #8651=IfcBeam('1WrzGm1SD2ev45B_OWQ38h',#18,'M_Concrete-Rectangular Beam:300 x 600mm:124655',$,'M_Concrete-Rectangular Beam:300 x 600mm',#8650,#8647,'124655',.JOIST.), #8828=IfcBeam('1WrzGm1SD2ev45B_OWQ38r',#18,'M_Concrete-Rectangular Beam:300 x 600mm:124657',$,'M_Concrete-Rectangular Beam:300 x 600mm',#8827,#8824,'124657',.JOIST.), #9005=IfcBeam('1WrzGm1SD2ev45B_OWQ38t',#18,'M_Concrete-Rectangular Beam:300 x 600mm:124659',$,'M_Concrete-Rectangular Beam:300 x 600mm',#9004,#90 ...

# %% [markdown]
# The valid and invalid beams gathered above can be used in visualizations like created whit script below, alowing to see in an 3D model the exact location of the beams:

# %%
settings = ifcopenshell.geom.settings()
settings.set(settings.USE_WORLD_COORDS, True)
plot = k3d.plot()

for product in ifc.by_type('IfcProduct'):
    if product.is_a('IfcOpeningElement') or product.is_a('IfcSpace'):
        continue
    if product.Representation:
        if product in invalid_beams:
            opacity = 1.0
            color = 0xff0000
        else:
            opacity = 0.15
            color = 0x0000ff
        shape = ifcopenshell.geom.create_shape(settings, product)
        vertices = shape.geometry.verts
        faces = shape.geometry.faces
        plot += k3d.mesh(vertices, faces, opacity=opacity, color=color)

plot.mode = 'Change'
plot.camera_mode = 'orbit'
plot.display()
# Out:
# Output()
